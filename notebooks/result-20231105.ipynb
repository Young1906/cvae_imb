# %%
import yaml
import numpy as np
import pandas as pd
from tabulate import tabulate

# %%
results = pd.concat([
    pd.read_csv("../results/baseline.csv", header=None),
    pd.read_csv("../results/mcmc.csv", header=None)])


results.columns = ["timestamp", "config", "precision", "recall", "f1_score"]
results.head()
# Out:
#                     timestamp                                         config  \
# 0  2023-11-11 18:03:44.827951  config/baseline/balance_catboost_baseline.yml
# 1  2023-11-11 18:03:58.811437   config/baseline/balance_catboost_smotenn.yml
# 2  2023-11-11 19:58:24.241044  config/baseline/balance_catboost_baseline.yml
# 3  2023-11-11 19:58:31.947361  config/baseline/balance_catboost_baseline.yml
# 4  2023-11-11 19:58:39.512772  config/baseline/balance_catboost_baseline.yml
#
#    precision   recall  f1_score
# 0    0.72953  0.70409   0.71001
# 1    0.72914  0.78395   0.72273
# 2    0.72953  0.70409   0.71001
# 3    0.72953  0.70409   0.71001
# 4    0.72953  0.70409   0.71001

# %%
def parse_config_clf(config):
    with open(f"../{config}", "r") as f:
        config = yaml.safe_load(f)
    
    if "baseline" in config.keys():
        return config["baseline"]["classifier"]
    else:
        return config["mcmc"]["classifier"]
    # return config["baseline"]["classifier"]

def parse_config_method(config):
    with open(f"../{config}", "r") as f:
        config = yaml.safe_load(f)
        
    if "baseline" in config.keys():
        return config["baseline"]["sampler_name"]
    else:
        return "mcmc"
        # return config["mcmc"]["classifier"]

def parse_config_dataset(config):
    with open(f"../{config}", "r") as f:
        config = yaml.safe_load(f)
        
    if "baseline" in config.keys():
        return config["baseline"]["dataset"]
    else:
        return config["mcmc"]["dataset"]

results["dataset"] = results.config.apply(parse_config_dataset)
results["classifier"] = results.config.apply(parse_config_clf)
results["method"] = results.config.apply(parse_config_method)

# %%
for ds in results.dataset.unique():
    rs = pd.pivot_table(
        results.query(f"dataset=='{ds}'"),
        index=["method"],
        columns = "classifier",
        values="f1_score",
        aggfunc=lambda x: f"{np.mean(x):.4f}"
        # aggfunc= lambda x: f"{np.mean(x):.4f}±{np.std(x):.4f}"
    )
    print(f"#### {ds}")
    print("\n")
    print(tabulate(rs, headers=rs.columns, tablefmt="github"))
    print("\n\n\n")
# Out:
# #### balance
#
#
# |                             |   catboost |   decision_tree |    gbc |    knn |     lr |    mlp |    svm |
# |-----------------------------|------------|-----------------|--------|--------|--------|--------|--------|
# | baseline                    |     0.71   |          0.5938 | 0.6097 | 0.6411 | 0.6071 | 0.7555 | 0.6337 |
# | instance-hardness-threshold |     0.5424 |          0.5138 | 0.5281 | 0.5653 | 0.5851 | 0.667  | 0.5402 |
# | mcmc                        |     0.6466 |          0.574  | 0.6354 | 0.5827 | 0.7019 | 0.7138 | 0.662  |
# | smotenn                     |     0.7101 |          0.6063 | 0.6555 | 0.6183 | 0.614  | 0.7452 | 0.7241 |
# | svm-smote                   |     0.663  |          0.5896 | 0.609  | 0.564  | 0.8633 | 0.8478 | 0.7438 |
#
#
#
#
# #### breast-cancer
#
#
# |                             |   catboost |   decision_tree |    gbc |    knn |     lr |    mlp |    svm |
# |-----------------------------|------------|-----------------|--------|--------|--------|--------|--------|
# | adasyn                      |     0.9623 |          0.9283 | 0.9656 | 0.9311 | 0.9645 | 0.9747 | 0.9597 |
# | baseline                    |     0.9619 |          0.9246 | 0.9521 | 0.9619 | 0.9811 | 0.9623 | 0.9623 |
# | instance-hardness-threshold |     0.926  |          0.9016 | 0.9072 | 0.9668 | 0.9523 | 0.9572 | 0.9337 |
# | kmean-smote                 |     0.9613 |          0.9367 | 0.9521 | 0.9576 | 0.9811 | 0.9741 | 0.9642 |
# | mcmc                        |     0.9556 |          0.9203 | 0.9516 | 0.9619 | 0.9799 | 0.9717 | 0.9648 |
# | smotenn                     |     0.9531 |          0.9328 | 0.9529 | 0.9598 | 0.9731 | 0.9711 | 0.9617 |
# | svm-smote                   |     0.9679 |          0.9297 | 0.9542 | 0.9399 | 0.9682 | 0.9705 | 0.9636 |
#
#
#
#
# #### breast-tissue
#
#
# |                             |   catboost |   decision_tree |    gbc |    knn |     lr |    mlp |    svm |
# |-----------------------------|------------|-----------------|--------|--------|--------|--------|--------|
# | baseline                    |     0.8476 |          0.6521 | 0.6819 | 0.664  | 0.6944 | 0.5787 | 0.6529 |
# | instance-hardness-threshold |     0.6232 |          0.6533 | 0.5776 | 0.6285 | 0.6303 | 0.65   | 0.6086 |
# | kmean-smote                 |     0.7586 |          0.6074 | 0.6565 | 0.67   | 0.6573 | 0.5835 | 0.6458 |
# | mcmc                        |     0.812  |          0.6387 | 0.6755 | 0.6564 | 0.7    | 0.6055 | 0.5945 |
# | smotenn                     |     0.5073 |          0.4291 | 0.3745 | 0.4605 | 0.5034 | 0.5044 | 0.447  |
# | svm-smote                   |     0.774  |          0.6218 | 0.647  | 0.6414 | 0.6693 | 0.5784 | 0.5798 |
#
#
#
#
# #### connectionist
#
#
# |                             |   catboost |   decision_tree |    gbc |    knn |     lr |    mlp |    svm |
# |-----------------------------|------------|-----------------|--------|--------|--------|--------|--------|
# | baseline                    |     0.8078 |          0.7846 | 0.7614 | 0.8078 | 0.6659 | 0.8558 | 0.7856 |
# | instance-hardness-threshold |     0.7155 |          0.715  | 0.7513 | 0.7434 | 0.7004 | 0.7725 | 0.7775 |
# | kmean-smote                 |     0.7923 |          0.719  | 0.7848 | 0.8226 | 0.6675 | 0.8403 | 0.7982 |
# | mcmc                        |     0.7971 |          0.7097 | 0.7927 | 0.8078 | 0.6708 | 0.8355 | 0.795  |
# | smotenn                     |     0.7238 |          0.7195 | 0.7216 | 0.7421 | 0.7236 | 0.7514 | 0.7603 |
# | svm-smote                   |     0.7892 |          0.7219 | 0.7945 | 0.834  | 0.6659 | 0.8323 | 0.7887 |
#
#
#
#
# #### ecoli
#
#
# |                             |   catboost |   decision_tree |    gbc |    knn |     lr |    mlp |    svm |
# |-----------------------------|------------|-----------------|--------|--------|--------|--------|--------|
# | adasyn                      |     0.9043 |          0.8457 | 0.855  | 0.8469 | 0.8372 | 0.8622 | 0.8955 |
# | baseline                    |     0.9145 |          0.8201 | 0.8538 | 0.8955 | 0.747  | 0.7976 | 0.9343 |
# | instance-hardness-threshold |     0.8291 |          0.7831 | 0.8103 | 0.9109 | 0.8719 | 0.9006 | 0.887  |
# | kmean-smote                 |     0.9145 |          0.8915 | 0.8932 | 0.8955 | 0.8429 | 0.8786 | 0.9158 |
# | smotenn                     |     0.894  |          0.8613 | 0.8685 | 0.917  | 0.8721 | 0.8768 | 0.9132 |
# | svm-smote                   |     0.8835 |          0.8544 | 0.8582 | 0.8789 | 0.8206 | 0.871  | 0.8743 |
#
#
#
#
# #### frogs
#
#
# |                             |   catboost |   decision_tree |    gbc |    knn |     lr |    mlp |    svm |
# |-----------------------------|------------|-----------------|--------|--------|--------|--------|--------|
# | adasyn                      |     0.9919 |          0.9687 | 0.9817 | 0.9897 | 0.9102 | 0.9876 | 0.9875 |
# | baseline                    |     0.9919 |          0.9706 | 0.9765 | 0.9926 | 0.9419 | 0.9868 | 0.9846 |
# | instance-hardness-threshold |     0.9424 |          0.9244 | 0.9345 | 0.9712 | 0.8945 | 0.9513 | 0.937  |
# | kmean-smote                 |     0.9907 |          0.9674 | 0.9783 | 0.9934 | 0.9415 | 0.9868 | 0.9836 |
# | mcmc                        |     0.9899 |          0.964  | 0.9755 | 0.9926 | 0.9422 | 0.9872 | 0.9808 |
# | smotenn                     |     0.9905 |          0.9657 | 0.9803 | 0.9922 | 0.9436 | 0.989  | 0.9853 |
# | svm-smote                   |     0.991  |          0.9692 | 0.9805 | 0.9908 | 0.9075 | 0.9879 | 0.9863 |
#
#
#
#
# #### heart_2cl
#
#
# |                             |   catboost |   decision_tree |    gbc |    knn |     lr |    mlp |    svm |
# |-----------------------------|------------|-----------------|--------|--------|--------|--------|--------|
# | adasyn                      |     0.7994 |          0.6784 | 0.7621 | 0.5495 | 0.7386 | 0.7598 | 0.7654 |
# | baseline                    |     0.6717 |          0.5055 | 0.5897 | 0.4764 | 0.8    | 0.7765 | 0.4433 |
# | instance-hardness-threshold |     0.6207 |          0.6077 | 0.6165 | 0.5146 | 0.6428 | 0.6633 | 0.6255 |
# | mcmc                        |     0.6928 |          0.6046 | 0.6982 | 0.4764 | 0.7784 | 0.6987 | 0.4543 |
# | smotenn                     |     0.6549 |          0.6787 | 0.6692 | 0.484  | 0.7129 | 0.7078 | 0.7068 |
# | svm-smote                   |     0.7792 |          0.6399 | 0.733  | 0.5809 | 0.7287 | 0.7031 | 0.7511 |
#
#
#
#
# #### ionosphere
#
#
# |                             |   catboost |   decision_tree |    gbc |    knn |     lr |    mlp |    svm |
# |-----------------------------|------------|-----------------|--------|--------|--------|--------|--------|
# | adasyn                      |     0.934  |          0.8293 | 0.9361 | 0.8656 | 0.8531 | 0.8994 | 0.9435 |
# | baseline                    |     0.9357 |          0.8598 | 0.9523 | 0.7912 | 0.8309 | 0.8861 | 0.9035 |
# | instance-hardness-threshold |     0.9382 |          0.864  | 0.8921 | 0.8474 | 0.81   | 0.8323 | 0.9462 |
# | kmean-smote                 |     0.9248 |          0.877  | 0.945  | 0.8307 | 0.8321 | 0.8849 | 0.9069 |
# | mcmc                        |     0.933  |          0.8707 | 0.944  | 0.7952 | 0.8279 | 0.8827 | 0.9035 |
# | smotenn                     |     0.8698 |          0.8351 | 0.878  | 0.8423 | 0.8105 | 0.8516 | 0.9011 |
# | svm-smote                   |     0.9237 |          0.8443 | 0.9415 | 0.8435 | 0.8173 | 0.8854 | 0.9194 |
#
#
#
#
# #### parkinsons
#
#
# |                             |   catboost |   decision_tree |    gbc |    knn |     lr |    mlp |    svm |
# |-----------------------------|------------|-----------------|--------|--------|--------|--------|--------|
# | adasyn                      |     0.9023 |          0.7949 | 0.914  | 0.8335 | 0.7792 | 0.8934 | 0.8246 |
# | baseline                    |     0.8872 |          0.7565 | 0.8872 | 0.812  | 0.6869 | 0.8427 | 0.7936 |
# | instance-hardness-threshold |     0.7334 |          0.7107 | 0.6955 | 0.7298 | 0.7114 | 0.715  | 0.7087 |
# | kmean-smote                 |     0.8914 |          0.8763 | 0.8945 | 0.8583 | 0.6984 | 0.8842 | 0.7936 |
# | mcmc                        |     0.8903 |          0.783  | 0.8804 | 0.8101 | 0.7163 | 0.8097 | 0.7917 |
# | smotenn                     |     0.8647 |          0.7483 | 0.8591 | 0.8341 | 0.7234 | 0.8288 | 0.7907 |
# | svm-smote                   |     0.9039 |          0.8148 | 0.9112 | 0.8162 | 0.7536 | 0.9183 | 0.8315 |

# %%
for ds in results.dataset.unique():
    rs = pd.pivot_table(
        results.query(f"dataset=='{ds}'"),
        index=["method"],
        columns = "classifier",
        values="precision",
    )
    print(f"#### {ds}")
    print("\n")
    print(tabulate(rs, headers=rs.columns, tablefmt="github"))
    print("\n\n\n")
# Out:
# #### balance
#
#
# |                             |   catboost |   decision_tree |      gbc |      knn |       lr |      mlp |      svm |
# |-----------------------------|------------|-----------------|----------|----------|----------|----------|----------|
# | baseline                    |   0.72953  |        0.61221  | 0.59979  | 0.64049  | 0.59176  | 0.95688  | 0.60931  |
# | instance-hardness-threshold |   0.712785 |        0.663007 | 0.690083 | 0.717733 | 0.723949 | 0.729977 | 0.717533 |
# | mcmc                        |   0.646267 |        0.593786 | 0.634303 | 0.632607 | 0.727687 | 0.725164 | 0.673707 |
# | smotenn                     |   0.733337 |        0.632902 | 0.668743 | 0.705451 | 0.728955 | 0.764173 | 0.753707 |
# | svm-smote                   |   0.664648 |        0.608201 | 0.597971 | 0.598577 | 0.840949 | 0.844627 | 0.741913 |
#
#
#
#
# #### breast-cancer
#
#
# |                             |   catboost |   decision_tree |      gbc |      knn |       lr |      mlp |      svm |
# |-----------------------------|------------|-----------------|----------|----------|----------|----------|----------|
# | adasyn                      |   0.9623   |        0.933563 | 0.972037 | 0.924826 | 0.960956 | 0.978386 | 0.960369 |
# | baseline                    |   0.96723  |        0.9246   | 0.96051  | 0.96723  | 0.98115  | 0.9623   | 0.9623   |
# | instance-hardness-threshold |   0.920069 |        0.89538  | 0.900708 | 0.965753 | 0.947035 | 0.952494 | 0.926896 |
# | kmean-smote                 |   0.966782 |        0.940537 | 0.96051  | 0.961551 | 0.98115  | 0.975987 | 0.964662 |
# | mcmc                        |   0.960909 |        0.92421  | 0.958539 | 0.96723  | 0.980211 | 0.972862 | 0.965449 |
# | smotenn                     |   0.957351 |        0.937918 | 0.959859 | 0.960306 | 0.971497 | 0.970899 | 0.961817 |
# | svm-smote                   |   0.969079 |        0.933893 | 0.960026 | 0.935203 | 0.965328 | 0.969277 | 0.963029 |
#
#
#
#
# #### breast-tissue
#
#
# |                             |   catboost |   decision_tree |      gbc |      knn |       lr |      mlp |      svm |
# |-----------------------------|------------|-----------------|----------|----------|----------|----------|----------|
# | baseline                    |   0.86111  |        0.65278  | 0.69643  | 0.66667  | 0.70556  | 0.55556  | 0.625    |
# | instance-hardness-threshold |   0.661906 |        0.685781 | 0.599206 | 0.66389  | 0.706852 | 0.707803 | 0.636112 |
# | kmean-smote                 |   0.78074  |        0.599128 | 0.68638  | 0.696825 | 0.669445 | 0.588096 | 0.663943 |
# | mcmc                        |   0.820739 |        0.65389  | 0.728625 | 0.658707 | 0.719816 | 0.619789 | 0.589498 |
# | smotenn                     |   0.506113 |        0.47633  | 0.375899 | 0.498069 | 0.528347 | 0.49928  | 0.477633 |
# | svm-smote                   |   0.791111 |        0.625507 | 0.677358 | 0.666297 | 0.709261 | 0.549948 | 0.555215 |
#
#
#
#
# #### connectionist
#
#
# |                             |   catboost |   decision_tree |      gbc |      knn |       lr |      mlp |      svm |
# |-----------------------------|------------|-----------------|----------|----------|----------|----------|----------|
# | baseline                    |   0.8125   |        0.80118  | 0.76136  | 0.8125   | 0.67361  | 0.86111  | 0.78571  |
# | instance-hardness-threshold |   0.720505 |        0.725561 | 0.762921 | 0.755407 | 0.711915 | 0.781233 | 0.81578  |
# | kmean-smote                 |   0.79486  |        0.728666 | 0.786147 | 0.82546  | 0.675003 | 0.843103 | 0.798977 |
# | mcmc                        |   0.799865 |        0.717361 | 0.7942   | 0.8125   | 0.677823 | 0.839443 | 0.795641 |
# | smotenn                     |   0.725791 |        0.725973 | 0.736039 | 0.753649 | 0.726245 | 0.752857 | 0.765205 |
# | svm-smote                   |   0.791569 |        0.732526 | 0.795596 | 0.836182 | 0.67361  | 0.834955 | 0.792758 |
#
#
#
#
# #### ecoli
#
#
# |                             |   catboost |   decision_tree |      gbc |      knn |       lr |      mlp |      svm |
# |-----------------------------|------------|-----------------|----------|----------|----------|----------|----------|
# | adasyn                      |   0.92719  |        0.858123 | 0.864211 | 0.835147 | 0.816623 | 0.844789 | 0.90503  |
# | baseline                    |   0.93651  |        0.8631   | 0.86226  | 0.90503  | 0.8625   | 0.93333  | 0.97273  |
# | instance-hardness-threshold |   0.814357 |        0.767877 | 0.800537 | 0.907826 | 0.872415 | 0.916151 | 0.875095 |
# | kmean-smote                 |   0.93651  |        0.900446 | 0.901603 | 0.90503  | 0.890806 | 0.893414 | 0.938925 |
# | smotenn                     |   0.90413  |        0.875691 | 0.884834 | 0.916529 | 0.856362 | 0.862249 | 0.934411 |
# | svm-smote                   |   0.886867 |        0.862739 | 0.853401 | 0.864714 | 0.800025 | 0.85497  | 0.872248 |
#
#
#
#
# #### frogs
#
#
# |                             |   catboost |   decision_tree |      gbc |      knn |       lr |      mlp |      svm |
# |-----------------------------|------------|-----------------|----------|----------|----------|----------|----------|
# | adasyn                      |   0.991378 |        0.968684 | 0.979987 | 0.989051 | 0.905072 | 0.987567 | 0.985853 |
# | baseline                    |   0.99243  |        0.9716   | 0.97782  | 0.99368  | 0.94361  | 0.98712  | 0.98542  |
# | instance-hardness-threshold |   0.936783 |        0.919404 | 0.928948 | 0.967404 | 0.890473 | 0.945817 | 0.931631 |
# | kmean-smote                 |   0.990975 |        0.96867  | 0.979341 | 0.994175 | 0.941127 | 0.986591 | 0.983645 |
# | mcmc                        |   0.990238 |        0.964735 | 0.976835 | 0.99368  | 0.943895 | 0.986842 | 0.981539 |
# | smotenn                     |   0.990522 |        0.966002 | 0.980627 | 0.992749 | 0.942533 | 0.988657 | 0.985525 |
# | svm-smote                   |   0.990357 |        0.968732 | 0.978629 | 0.990327 | 0.902473 | 0.987084 | 0.984227 |
#
#
#
#
# #### heart_2cl
#
#
# |                             |   catboost |   decision_tree |      gbc |      knn |       lr |      mlp |      svm |
# |-----------------------------|------------|-----------------|----------|----------|----------|----------|----------|
# | adasyn                      |   0.810436 |        0.674007 | 0.783436 | 0.636484 | 0.728585 | 0.780091 | 0.746843 |
# | baseline                    |   0.92157  |        0.50714  | 0.7451   | 0.47917  | 0.87538  | 0.82065  | 0.39815  |
# | instance-hardness-threshold |   0.680096 |        0.653293 | 0.662027 | 0.649398 | 0.690518 | 0.698569 | 0.683944 |
# | mcmc                        |   0.827982 |        0.61142  | 0.766502 | 0.47917  | 0.830161 | 0.756069 | 0.465562 |
# | smotenn                     |   0.679399 |        0.679422 | 0.670156 | 0.642524 | 0.71592  | 0.71737  | 0.716585 |
# | svm-smote                   |   0.796741 |        0.636261 | 0.784415 | 0.638197 | 0.717258 | 0.718294 | 0.733997 |
#
#
#
#
# #### ionosphere
#
#
# |                             |   catboost |   decision_tree |      gbc |      knn |       lr |      mlp |      svm |
# |-----------------------------|------------|-----------------|----------|----------|----------|----------|----------|
# | adasyn                      |   0.943561 |        0.833319 | 0.946536 | 0.90515  | 0.877801 | 0.914469 | 0.951384 |
# | baseline                    |   0.96     |        0.86348  | 0.96939  | 0.86845  | 0.88725  | 0.91618  | 0.92619  |
# | instance-hardness-threshold |   0.939169 |        0.858187 | 0.885892 | 0.895483 | 0.823344 | 0.833421 | 0.949335 |
# | kmean-smote                 |   0.940062 |        0.887551 | 0.960777 | 0.887275 | 0.877375 | 0.909633 | 0.928244 |
# | mcmc                        |   0.951615 |        0.879944 | 0.958591 | 0.870329 | 0.881829 | 0.913623 | 0.92619  |
# | smotenn                     |   0.909923 |        0.853279 | 0.916557 | 0.892959 | 0.864245 | 0.900391 | 0.924942 |
# | svm-smote                   |   0.939436 |        0.850465 | 0.960396 | 0.893598 | 0.856753 | 0.907149 | 0.935775 |
#
#
#
#
# #### parkinsons
#
#
# |                             |   catboost |   decision_tree |      gbc |      knn |       lr |      mlp |      svm |
# |-----------------------------|------------|-----------------|----------|----------|----------|----------|----------|
# | adasyn                      |   0.89123  |        0.808957 | 0.909167 | 0.817583 | 0.764814 | 0.899459 | 0.813866 |
# | baseline                    |   0.95312  |        0.76667  | 0.95312  | 0.86607  | 0.69444  | 0.93939  | 0.92647  |
# | instance-hardness-threshold |   0.736483 |        0.719327 | 0.709159 | 0.744892 | 0.739523 | 0.743112 | 0.739771 |
# | kmean-smote                 |   0.947109 |        0.936423 | 0.943416 | 0.883352 | 0.702611 | 0.952205 | 0.92647  |
# | mcmc                        |   0.899356 |        0.787981 | 0.903198 | 0.862364 | 0.721907 | 0.864865 | 0.920766 |
# | smotenn                     |   0.861618 |        0.746923 | 0.851283 | 0.816591 | 0.712437 | 0.811906 | 0.775335 |
# | svm-smote                   |   0.895324 |        0.820669 | 0.908508 | 0.802786 | 0.740662 | 0.915609 | 0.814671 |

# %%
for ds in results.dataset.unique():
    rs = pd.pivot_table(
        results.query(f"dataset=='{ds}'"),
        index=["method"],
        columns = "classifier",
        values="recall",
    )
    print(f"#### {ds}")
    print("\n")
    print(tabulate(rs, headers=rs.columns, tablefmt="github"))
    print("\n\n\n")
# Out:
# #### balance
#
#
# |                             |   catboost |   decision_tree |      gbc |      knn |       lr |      mlp |      svm |
# |-----------------------------|------------|-----------------|----------|----------|----------|----------|----------|
# | baseline                    |   0.70409  |        0.58375  | 0.62019  | 0.64202  | 0.63158  | 0.73333  | 0.66082  |
# | instance-hardness-threshold |   0.670605 |        0.583411 | 0.641389 | 0.694699 | 0.719136 | 0.786578 | 0.677315 |
# | mcmc                        |   0.651349 |        0.559448 | 0.648572 | 0.581665 | 0.776872 | 0.762122 | 0.670991 |
# | smotenn                     |   0.796437 |        0.616775 | 0.669323 | 0.715433 | 0.747217 | 0.85568  | 0.834816 |
# | svm-smote                   |   0.664152 |        0.579901 | 0.621396 | 0.536659 | 0.910275 | 0.853981 | 0.780561 |
#
#
#
#
# #### breast-cancer
#
#
# |                             |   catboost |   decision_tree |      gbc |      knn |       lr |      mlp |      svm |
# |-----------------------------|------------|-----------------|----------|----------|----------|----------|----------|
# | adasyn                      |   0.9623   |        0.924206 | 0.960451 | 0.940872 | 0.96865  | 0.971562 | 0.959127 |
# | baseline                    |   0.95734  |        0.9246   | 0.94544  | 0.95734  | 0.98115  | 0.9623   | 0.9623   |
# | instance-hardness-threshold |   0.934851 |        0.918387 | 0.921363 | 0.967858 | 0.959392 | 0.963096 | 0.945039 |
# | kmean-smote                 |   0.956547 |        0.933531 | 0.94544  | 0.954101 | 0.98115  | 0.972423 | 0.96369  |
# | mcmc                        |   0.951059 |        0.917525 | 0.946297 | 0.95734  | 0.979563 | 0.970571 | 0.964153 |
# | smotenn                     |   0.949537 |        0.929101 | 0.947225 | 0.959459 | 0.974804 | 0.97143  | 0.961507 |
# | svm-smote                   |   0.966799 |        0.926455 | 0.949473 | 0.946163 | 0.97143  | 0.97196  | 0.964219 |
#
#
#
#
# #### breast-tissue
#
#
# |                             |   catboost |   decision_tree |      gbc |      knn |       lr |      mlp |      svm |
# |-----------------------------|------------|-----------------|----------|----------|----------|----------|----------|
# | baseline                    |   0.86111  |        0.66111  | 0.70278  | 0.675    | 0.70833  | 0.61111  | 0.70278  |
# | instance-hardness-threshold |   0.662223 |        0.680927 | 0.609073 | 0.656483 | 0.669258 | 0.681111 | 0.654631 |
# | kmean-smote                 |   0.768518 |        0.645371 | 0.681481 | 0.696483 | 0.678704 | 0.625185 | 0.683333 |
# | mcmc                        |   0.818889 |        0.662036 | 0.689815 | 0.67     | 0.71574  | 0.649629 | 0.634444 |
# | smotenn                     |   0.576111 |        0.514445 | 0.468889 | 0.541297 | 0.576111 | 0.588888 | 0.539259 |
# | svm-smote                   |   0.787779 |        0.653704 | 0.676853 | 0.675743 | 0.695742 | 0.631482 | 0.637036 |
#
#
#
#
# #### connectionist
#
#
# |                             |   catboost |   decision_tree |      gbc |      knn |       lr |      mlp |      svm |
# |-----------------------------|------------|-----------------|----------|----------|----------|----------|----------|
# | baseline                    |   0.80682  |        0.79091  | 0.76136  | 0.80682  | 0.67045  | 0.85455  | 0.78636  |
# | instance-hardness-threshold |   0.718484 |        0.719242 | 0.756364 | 0.748787 | 0.706058 | 0.776516 | 0.788634 |
# | kmean-smote                 |   0.791667 |        0.722577 | 0.784544 | 0.82182  | 0.671965 | 0.839397 | 0.799089 |
# | mcmc                        |   0.796364 |        0.712726 | 0.792272 | 0.80682  | 0.674996 | 0.834699 | 0.795757 |
# | smotenn                     |   0.723485 |        0.719698 | 0.723182 | 0.742576 | 0.725455 | 0.751515 | 0.760606 |
# | svm-smote                   |   0.788636 |        0.725757 | 0.794241 | 0.833789 | 0.67045  | 0.831517 | 0.791214 |
#
#
#
#
# #### ecoli
#
#
# |                             |   catboost |   decision_tree |      gbc |      knn |       lr |      mlp |      svm |
# |-----------------------------|------------|-----------------|----------|----------|----------|----------|----------|
# | adasyn                      |   0.886375 |        0.835737 | 0.846791 | 0.861536 | 0.872755 | 0.887498 | 0.88702  |
# | baseline                    |   0.89663  |        0.79327  | 0.84615  | 0.88702  | 0.70913  | 0.75     | 0.90625  |
# | instance-hardness-threshold |   0.84984  |        0.816507 | 0.823398 | 0.914422 | 0.871953 | 0.889579 | 0.901603 |
# | kmean-smote                 |   0.89663  |        0.883654 | 0.885737 | 0.88702  | 0.817304 | 0.866987 | 0.897271 |
# | smotenn                     |   0.884937 |        0.849999 | 0.855289 | 0.917629 | 0.893268 | 0.895832 | 0.895989 |
# | svm-smote                   |   0.880606 |        0.847595 | 0.864262 | 0.897116 | 0.862501 | 0.892627 | 0.876921 |
#
#
#
#
# #### frogs
#
#
# |                             |   catboost |   decision_tree |      gbc |      knn |       lr |      mlp |      svm |
# |-----------------------------|------------|-----------------|----------|----------|----------|----------|----------|
# | adasyn                      |   0.992527 |        0.968759 | 0.983541 | 0.990364 | 0.921554 | 0.987605 | 0.989342 |
# | baseline                    |   0.99143  |        0.96966  | 0.97519  | 0.99166  | 0.94023  | 0.98647  | 0.98376  |
# | instance-hardness-threshold |   0.953467 |        0.937156 | 0.946389 | 0.976199 | 0.909545 | 0.960565 | 0.947619 |
# | kmean-smote                 |   0.990443 |        0.966227 | 0.977307 | 0.992628 | 0.942011 | 0.986943 | 0.983507 |
# | mcmc                        |   0.989617 |        0.963367 | 0.974322 | 0.99166  | 0.940651 | 0.987573 | 0.980097 |
# | smotenn                     |   0.990412 |        0.965349 | 0.980059 | 0.991703 | 0.944808 | 0.989369 | 0.985133 |
# | svm-smote                   |   0.991698 |        0.969724 | 0.982509 | 0.991219 | 0.919531 | 0.988749 | 0.98854  |
#
#
#
#
# #### heart_2cl
#
#
# |                             |   catboost |   decision_tree |      gbc |      knn |       lr |      mlp |      svm |
# |-----------------------------|------------|-----------------|----------|----------|----------|----------|----------|
# | adasyn                      |   0.790135 |        0.692107 | 0.746934 | 0.700071 | 0.752287 | 0.745384 | 0.800565 |
# | baseline                    |   0.63636  |        0.50846  | 0.57928  | 0.48732  | 0.7611   | 0.74947  | 0.5      |
# | instance-hardness-threshold |   0.772939 |        0.732277 | 0.745948 | 0.699224 | 0.790699 | 0.805427 | 0.778295 |
# | mcmc                        |   0.660324 |        0.605851 | 0.673643 | 0.48732  | 0.751021 | 0.677379 | 0.504509 |
# | smotenn                     |   0.775334 |        0.761099 | 0.750387 | 0.678295 | 0.82537  | 0.831219 | 0.830445 |
# | svm-smote                   |   0.768147 |        0.650246 | 0.709936 | 0.709867 | 0.746088 | 0.692885 | 0.784565 |
#
#
#
#
# #### ionosphere
#
#
# |                             |   catboost |   decision_tree |      gbc |      knn |       lr |      mlp |      svm |
# |-----------------------------|------------|-----------------|----------|----------|----------|----------|----------|
# | adasyn                      |   0.926347 |        0.828085 | 0.928405 | 0.846463 | 0.839361 | 0.889159 | 0.93713  |
# | baseline                    |   0.92     |        0.85652  | 0.94     | 0.76913  | 0.80913  | 0.86913  | 0.88913  |
# | instance-hardness-threshold |   0.937651 |        0.875881 | 0.904085 | 0.826463 | 0.801505 | 0.8571   | 0.943449 |
# | kmean-smote                 |   0.913855 |        0.870173 | 0.93371  | 0.80913  | 0.812666 | 0.870115 | 0.89313  |
# | mcmc                        |   0.920261 |        0.865216 | 0.933594 | 0.77313  | 0.806956 | 0.865739 | 0.88913  |
# | smotenn                     |   0.850579 |        0.8251   | 0.859304 | 0.82113  | 0.790608 | 0.830579 | 0.886463 |
# | svm-smote                   |   0.912521 |        0.842607 | 0.928493 | 0.822463 | 0.800086 | 0.871941 | 0.907797 |
#
#
#
#
# #### parkinsons
#
#
# |                             |   catboost |   decision_tree |      gbc |      knn |       lr |      mlp |      svm |
# |-----------------------------|------------|-----------------|----------|----------|----------|----------|----------|
# | adasyn                      |   0.91552  |        0.786323 | 0.920232 | 0.898963 | 0.807123 | 0.889197 | 0.84023  |
# | baseline                    |   0.85     |        0.74828  | 0.85     | 0.78276  | 0.68103  | 0.8      | 0.75     |
# | instance-hardness-threshold |   0.807243 |        0.783565 | 0.772071 | 0.818966 | 0.812757 | 0.817238 | 0.812639 |
# | kmean-smote                 |   0.858251 |        0.842069 | 0.865403 | 0.841496 | 0.695398 | 0.846667 | 0.75     |
# | mcmc                        |   0.88368  |        0.782644 | 0.867128 | 0.781611 | 0.713331 | 0.781611 | 0.748851 |
# | smotenn                     |   0.868739 |        0.751034 | 0.870692 | 0.888159 | 0.748734 | 0.869538 | 0.830227 |
# | svm-smote                   |   0.914485 |        0.815059 | 0.914715 | 0.879883 | 0.784481 | 0.922531 | 0.861031 |

# %%
results.head()
# Out:
#                     timestamp                                         config  \
# 0  2023-11-11 18:03:44.827951  config/baseline/balance_catboost_baseline.yml
# 1  2023-11-11 18:03:58.811437   config/baseline/balance_catboost_smotenn.yml
# 2  2023-11-11 19:58:24.241044  config/baseline/balance_catboost_baseline.yml
# 3  2023-11-11 19:58:31.947361  config/baseline/balance_catboost_baseline.yml
# 4  2023-11-11 19:58:39.512772  config/baseline/balance_catboost_baseline.yml
#
#    precision   recall  f1_score  dataset classifier    method
# 0    0.72953  0.70409   0.71001  balance   catboost  baseline
# 1    0.72914  0.78395   0.72273  balance   catboost   smotenn
# 2    0.72953  0.70409   0.71001  balance   catboost  baseline
# 3    0.72953  0.70409   0.71001  balance   catboost  baseline
# 4    0.72953  0.70409   0.71001  balance   catboost  baseline

# %%
# plt.rcParams["figure.figsize"] = [3, 9]
rs = pd.pivot_table(
    results,
    index=["dataset", "classifier"],
    columns="method",
    values="f1_score"
).reset_index().fillna(0)
print(tabulate(rs, headers=rs.columns, tablefmt="github"))
# Out:
# |    | dataset       | classifier    |   adasyn |   baseline |   instance-hardness-threshold |   kmean-smote |     mcmc |   smotenn |   svm-smote |
# |----|---------------|---------------|----------|------------|-------------------------------|---------------|----------|-----------|-------------|
# |  0 | balance       | catboost      | 0        |    0.71001 |                      0.542369 |      0        | 0.646565 |  0.710061 |    0.663022 |
# |  1 | balance       | decision_tree | 0        |    0.59377 |                      0.513811 |      0        | 0.573965 |  0.606283 |    0.589603 |
# |  2 | balance       | gbc           | 0        |    0.60965 |                      0.528087 |      0        | 0.635381 |  0.655518 |    0.609042 |
# |  3 | balance       | knn           | 0        |    0.64113 |                      0.565335 |      0        | 0.582711 |  0.618299 |    0.564004 |
# |  4 | balance       | lr            | 0        |    0.60709 |                      0.585141 |      0        | 0.701923 |  0.614043 |    0.863339 |
# |  5 | balance       | mlp           | 0        |    0.75546 |                      0.666998 |      0        | 0.713779 |  0.745214 |    0.84783  |
# |  6 | balance       | svm           | 0        |    0.63367 |                      0.540209 |      0        | 0.662032 |  0.724119 |    0.743762 |
# |  7 | breast-cancer | catboost      | 0.9623   |    0.96191 |                      0.926015 |      0.961258 | 0.955561 |  0.953085 |    0.967881 |
# |  8 | breast-cancer | decision_tree | 0.928347 |    0.9246  |                      0.901623 |      0.936709 | 0.920275 |  0.932797 |    0.929733 |
# |  9 | breast-cancer | gbc           | 0.965633 |    0.95213 |                      0.907239 |      0.95213  | 0.951628 |  0.952892 |    0.954213 |
# | 10 | breast-cancer | knn           | 0.931063 |    0.96191 |                      0.966761 |      0.957584 | 0.96191  |  0.959788 |    0.939891 |
# | 11 | breast-cancer | lr            | 0.9645   |    0.98115 |                      0.952334 |      0.98115  | 0.979874 |  0.973081 |    0.96818  |
# | 12 | breast-cancer | mlp           | 0.974705 |    0.9623  |                      0.957182 |      0.974132 | 0.971657 |  0.971113 |    0.970549 |
# | 13 | breast-cancer | svm           | 0.959724 |    0.9623  |                      0.933711 |      0.964156 | 0.964775 |  0.961656 |    0.963599 |
# | 14 | breast-tissue | catboost      | 0        |    0.84762 |                      0.623166 |      0.758553 | 0.811975 |  0.507267 |    0.773977 |
# | 15 | breast-tissue | decision_tree | 0        |    0.65212 |                      0.653323 |      0.607375 | 0.638702 |  0.42913  |    0.621792 |
# | 16 | breast-tissue | gbc           | 0        |    0.68191 |                      0.577565 |      0.656546 | 0.675549 |  0.374536 |    0.646973 |
# | 17 | breast-tissue | knn           | 0        |    0.66402 |                      0.628467 |      0.670017 | 0.656393 |  0.460533 |    0.641377 |
# | 18 | breast-tissue | lr            | 0        |    0.69444 |                      0.630314 |      0.657291 | 0.699955 |  0.503415 |    0.66933  |
# | 19 | breast-tissue | mlp           | 0        |    0.5787  |                      0.65     |      0.583527 | 0.605479 |  0.504445 |    0.578431 |
# | 20 | breast-tissue | svm           | 0        |    0.65291 |                      0.60856  |      0.645837 | 0.594484 |  0.447018 |    0.579795 |
# | 21 | connectionist | catboost      | 0        |    0.80778 |                      0.715469 |      0.79234  | 0.797088 |  0.723803 |    0.789239 |
# | 22 | connectionist | decision_tree | 0        |    0.78462 |                      0.714983 |      0.719026 | 0.709695 |  0.719456 |    0.72194  |
# | 23 | connectionist | gbc           | 0        |    0.76136 |                      0.751307 |      0.784825 | 0.792684 |  0.72163  |    0.794456 |
# | 24 | connectionist | knn           | 0        |    0.80778 |                      0.743421 |      0.8226   | 0.80778  |  0.742107 |    0.834036 |
# | 25 | connectionist | lr            | 0        |    0.66591 |                      0.700376 |      0.667536 | 0.670761 |  0.723555 |    0.66591  |
# | 26 | connectionist | mlp           | 0        |    0.85584 |                      0.772485 |      0.840267 | 0.835455 |  0.751372 |    0.832299 |
# | 27 | connectionist | svm           | 0        |    0.78559 |                      0.777494 |      0.79821  | 0.795017 |  0.760341 |    0.788745 |
# | 28 | ecoli         | catboost      | 0.904275 |    0.91447 |                      0.829107 |      0.91447  | 0        |  0.89396  |    0.883501 |
# | 29 | ecoli         | decision_tree | 0.845657 |    0.82011 |                      0.783103 |      0.89154  | 0        |  0.861275 |    0.854428 |
# | 30 | ecoli         | gbc           | 0.854956 |    0.85376 |                      0.810339 |      0.893181 | 0        |  0.868471 |    0.858173 |
# | 31 | ecoli         | knn           | 0.846863 |    0.89555 |                      0.91095  |      0.89555  | 0        |  0.91705  |    0.87895  |
# | 32 | ecoli         | lr            | 0.837179 |    0.74702 |                      0.871885 |      0.842939 | 0        |  0.87215  |    0.820642 |
# | 33 | ecoli         | mlp           | 0.862204 |    0.79762 |                      0.900583 |      0.878649 | 0        |  0.876766 |    0.871017 |
# | 34 | ecoli         | svm           | 0.89555  |    0.93426 |                      0.887049 |      0.915789 | 0        |  0.913209 |    0.874343 |
# | 35 | frogs         | catboost      | 0.991943 |    0.99193 |                      0.942371 |      0.990707 | 0.989923 |  0.990465 |    0.991017 |
# | 36 | frogs         | decision_tree | 0.968716 |    0.97061 |                      0.924429 |      0.967406 | 0.964021 |  0.965663 |    0.969191 |
# | 37 | frogs         | gbc           | 0.98169  |    0.97647 |                      0.934483 |      0.978301 | 0.975544 |  0.980339 |    0.980478 |
# | 38 | frogs         | knn           | 0.989701 |    0.99265 |                      0.971225 |      0.993391 | 0.99265  |  0.992219 |    0.990772 |
# | 39 | frogs         | lr            | 0.910223 |    0.94185 |                      0.894499 |      0.94155  | 0.942208 |  0.943638 |    0.907521 |
# | 40 | frogs         | mlp           | 0.987583 |    0.98679 |                      0.951291 |      0.986759 | 0.987202 |  0.989008 |    0.987897 |
# | 41 | frogs         | svm           | 0.987531 |    0.98458 |                      0.93696  |      0.983573 | 0.98081  |  0.985329 |    0.986277 |
# | 42 | heart_2cl     | catboost      | 0.799374 |    0.67173 |                      0.620659 |      0        | 0.692812 |  0.654882 |    0.779249 |
# | 43 | heart_2cl     | decision_tree | 0.678429 |    0.50554 |                      0.607746 |      0        | 0.604559 |  0.678719 |    0.639873 |
# | 44 | heart_2cl     | gbc           | 0.762123 |    0.58967 |                      0.616538 |      0        | 0.698246 |  0.669246 |    0.733027 |
# | 45 | heart_2cl     | knn           | 0.54947  |    0.47641 |                      0.514559 |      0        | 0.47641  |  0.483977 |    0.580893 |
# | 46 | heart_2cl     | lr            | 0.738629 |    0.8     |                      0.642804 |      0        | 0.778381 |  0.712891 |    0.728696 |
# | 47 | heart_2cl     | mlp           | 0.759791 |    0.77646 |                      0.66326  |      0        | 0.698719 |  0.707837 |    0.703092 |
# | 48 | heart_2cl     | svm           | 0.765432 |    0.4433  |                      0.625501 |      0        | 0.454253 |  0.706783 |    0.751078 |
# | 49 | ionosphere    | catboost      | 0.933961 |    0.93569 |                      0.938249 |      0.92482  | 0.932997 |  0.869792 |    0.923713 |
# | 50 | ionosphere    | decision_tree | 0.829251 |    0.85978 |                      0.864001 |      0.877025 | 0.870718 |  0.835051 |    0.844253 |
# | 51 | ionosphere    | gbc           | 0.936093 |    0.9523  |                      0.892108 |      0.944978 | 0.944021 |  0.878006 |    0.94148  |
# | 52 | ionosphere    | knn           | 0.865646 |    0.79118 |                      0.847365 |      0.830743 | 0.795179 |  0.842277 |    0.843499 |
# | 53 | ionosphere    | lr            | 0.853067 |    0.83095 |                      0.809991 |      0.832057 | 0.827899 |  0.810519 |    0.817274 |
# | 54 | ionosphere    | mlp           | 0.899429 |    0.88614 |                      0.832325 |      0.884852 | 0.882716 |  0.851632 |    0.885385 |
# | 55 | ionosphere    | svm           | 0.943515 |    0.90353 |                      0.946159 |      0.906922 | 0.90353  |  0.901068 |    0.919359 |
# | 56 | parkinsons    | catboost      | 0.90226  |    0.88717 |                      0.733395 |      0.891356 | 0.890282 |  0.864703 |    0.903851 |
# | 57 | parkinsons    | decision_tree | 0.794871 |    0.75647 |                      0.710729 |      0.876349 | 0.782963 |  0.748322 |    0.814778 |
# | 58 | parkinsons    | gbc           | 0.914018 |    0.88717 |                      0.695507 |      0.894469 | 0.88042  |  0.859051 |    0.911153 |
# | 59 | parkinsons    | knn           | 0.833467 |    0.81196 |                      0.729845 |      0.858328 | 0.810051 |  0.834124 |    0.816231 |
# | 60 | parkinsons    | lr            | 0.779198 |    0.68689 |                      0.711359 |      0.698446 | 0.716263 |  0.723367 |    0.753617 |
# | 61 | parkinsons    | mlp           | 0.893409 |    0.84274 |                      0.715046 |      0.884208 | 0.809687 |  0.828793 |    0.918301 |
# | 62 | parkinsons    | svm           | 0.824647 |    0.79365 |                      0.708722 |      0.79365  | 0.791681 |  0.790744 |    0.831535 |
